# %% [markdown]
# <a href="https://colab.research.google.com/github/BureddySaiPoojitha/Projects_AIML_-/blob/main/PROJECT_MODULE04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project for Module 4: Perceptron and Gradient Descent**

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 A Simple Cost Function

# %%
def f(x):
  return x**2+2*x+1

# %%
x_1 = np.linspace(start=-6, stop=6, num=450)

# %%
plt.xlim(-6 ,6)
plt.ylim(4, 12)
plt.xlabel('X', fontsize=15)
plt.ylabel('f(x)', fontsize=15)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# # Slope &  Derivatives

# %%
def df(x):
  return 3*x-1

# %%
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# # Gradient Descent

# %%
# Gradient Descent
# Task-1
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)  # [Required]
    new_x = previous_x - step_multiplier * gradient  # [Required]

    step_size = abs(new_x - previous_x)
    print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # [Required]

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# 0.7999999999999998
# 0.56
# 0.3919999999999999
# 0.2744000000000001
# 0.19208000000000003
# 0.13445600000000002
# 0.09411920000000007
# 0.06588344000000002
# 0.046118408
# 0.03228288560000003
# 0.02259801991999999
# 0.01581861394399997
# 0.01107302976079999
# 0.007751120832560021
# 0.00542578458279197
# 0.0037980492079544015
# 0.0026586344455680755
# 0.0018610441118976917
# 0.0013027308783283287
# 0.0009119116148298412
# 0.0006383381303808888
# 0.00044683669126666103
# 0.0003127856838866516
# 0.00021894997872062838
# 0.00015326498510448427
# 0.00010728548957311679
# 7.5099842701154e-05
# 5.256988989083e-05
# 3.679892292357545e-05
# 2.575924604653057e-05
# 1.8031472232560297e-05
# 1.2622030562792208e-05
# 8.835421393960097e-06
# Loop ran this many times: 32
# Local minimum occurs at: 0.33335394931658585
# Slope or df(x) value at this point is: 6.184794975760965e-05
# f(x) value or cost at this point is: 1.7778327541581365

# %%
plt.figure(figsize=[20, 5])

# 1 Chart: Cost function

plt.subplot(1, 3, 1)
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)
values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative

plt.subplot(1, 3, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)

plt.subplot(1, 3, 3)
plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)

plt.show()

# %% [markdown]
# # Example 2- Multiple Minima vs Initial Guess and Advanced Functions

# %%
# Task-2

x_2 = np.linspace(-3, 3, 900)
def g(x):
    return (x**4)-(4*x**2)+5  # [Required]

def dg(x):
    return 4*x**3-8*x  # [Required]

# %%
# Task-3
# Plot function and derivative side by side
plt.figure(figsize=[20, 5])

# 1 Chart: Function g(x)
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(-4, 4)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='green', linewidth=3, alpha=0.9)

# 2 Chart: Derivative dg(x)
plt.subplot(1, 2, 2)

plt.xlim(-3, 3)
plt.ylim(-5, 5)

plt.title('Derivative dg(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.plot(x_2, dg(x_2), color='orange', linewidth=3, alpha=0.9)

plt.show()

# %% [markdown]
# # Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.3, 0.05, 0.003)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 1.413980863212025
# Number of steps: 11

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.7,
                                                 multiplier=0.03, precision=0.0005)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.4136853490741939
# Number of steps: 15

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.4120887490901561
# Number of steps: 34

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[18, 9])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0.7, 5.9)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative

plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-3, 3)
plt.ylim(-6, 9)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=7, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)
plt.show()

# %% [markdown]
# # Example 3-Divergence and Overfolw

# %%
# Task-4

x_3 = np.linspace(-3, 3, 900)
def h(x):
    return x**5-2*x**4+2

def dh(x):
    return 5*x**4-8*x**3

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[16, 8])

# 1 Chart: Cost function

plt.subplot(1, 2, 1)
plt.xlim(-4, 4)
plt.ylim(0.4, 5.7)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative

plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-4, 4)
plt.ylim(-7, 9)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=7, alpha=0.7)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.7)
plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  14

# %%
# Define functions g(x) and dg(x)
def g(x):
    return (x**4) - (4*x**2) + 5

def dg(x):
    return 4*x**3 - 8*x

# Gradient Descent function (Assuming you have it defined earlier in your notebook)
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# Task-5: Run gradient descent 3 times
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Task-6: Visualization

plt.figure(figsize=[20, 5])

# 1 Chart: Function Plot

plt.subplot(1, 2, 1)
plt.title('Gradient Descent with Various Learning Rates', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

x_2 = np.linspace(-3, 3, 900)

plt.plot(x_2, g(x_2), color='green', linewidth=3, alpha=0.8)
for results, label, color in zip(
    [low_gamma, mid_gamma, high_gamma, insane_gamma],
    ['Low Gamma (0.0005)', 'Mid Gamma (0.001)', 'High Gamma (0.002)', 'Insane Gamma (0.25)'],
    ['blue', 'orange', 'red', 'purple']
):
    x_vals = results[1]
    plt.scatter(x_vals, [g(x) for x in x_vals], label=label, s=50, alpha=0.6, color=color)

plt.legend(fontsize=12)

# 2 Chart: Derivative Plot

plt.subplot(1, 2, 2)
plt.title('Derivative with Various Learning Rates', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.plot(x_2, dg(x_2), color='orange', linewidth=3, alpha=0.8)
for results, label, color in zip(
    [low_gamma, mid_gamma, high_gamma, insane_gamma],
    ['Low Gamma (0.0005)', 'Mid Gamma (0.001)', 'High Gamma (0.002)', 'Insane Gamma (0.25)'],
    ['blue', 'orange', 'red', 'purple']
):
    x_vals = results[1]
    plt.scatter(x_vals, [dg(x) for x in x_vals], label=label, s=50, alpha=0.6, color=color)

plt.legend(fontsize=12)
plt.show()

# %%
# TASK-7: Plot reduction in cost for each iteration

costs_low_gamma = [g(x) for x in low_gamma[1]]
costs_mid_gamma = [g(x) for x in mid_gamma[1]]
costs_high_gamma = [g(x) for x in high_gamma[1]]
costs_insane_gamma = [g(x) for x in insane_gamma[1]]

plt.figure(figsize=[12, 6])
plt.title('Cost Reduction per Iteration', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost (g(x))', fontsize=16)

for costs, label, color in zip(
    [costs_low_gamma, costs_mid_gamma, costs_high_gamma, costs_insane_gamma],
    ['Low Gamma (0.0005)', 'Mid Gamma (0.001)', 'High Gamma (0.002)', 'Insane Gamma (0.25)'],
    ['blue', 'orange', 'red', 'purple']
):
    plt.plot(range(len(costs)), costs, label=label, linewidth=2, alpha=0.8, color=color)

plt.legend(fontsize=12)
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# # Example 4- Data Viz with 3D Charts

# %%
# Task-8

x_4 = np.linspace(-3, 3, 900)

def f(x,y):
    return 1/(3**())

def dg(x):
    return ## [REQUIRED]

# %%
def f(x, y):
    r = 3 ** (-x**2 - y**2)
    return 1 / (r + 1)

# %%
x_4 = np.linspace(start=-3, stop=3, num=400)
y_4 = np.linspace(start=-3, stop=3, num=400)
print('Shape of X array', x_4.shape)
x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (400,)
# Array after meshgrid:  (400, 400)

# %%
fig = plt.figure(figsize=(26, 22))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)
ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.6)

plt.show()

# %% [markdown]
# ### Task 9
#
# # Partial Derivatives & Symbolic Computation
#
# df/dx=(2xln(3).r)/(r+1)^2
#
# df/dy=(2y ln(3).r)/(r+1)^2

# %%
a, b = symbols('x, y')
print('Our cost function f(x, y) is: ', f(a, b))
print('Partial derivative wrt x is: ', diff(f(a, b), b))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a:2.0, b:1.5}))
# Out:
# Our cost function f(x, y) is:  1/(3**(-x**2 - y**2) + 1)
# Partial derivative wrt x is:  2*3**(-x**2 - y**2)*y*log(3)/(3**(-x**2 - y**2) + 1)**2
# Value of f(x,y) at x=1.8 y=1.0 is:  0.990604794032582
# Value of partial derivative wrt x:  0.00457079500716959

# %% [markdown]
# # Batch Gradient Descent with SymPy

# %%
multiplier = 0.3
max_iter = 600
params = np.array([2.0, 1.5]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [1.99844499374799e-37 1.49883374531099e-37]
# Minimum occurs at x value of:  3.03859255300649e-37
# Minimum occurs at y value of:  2.27894441475487e-37
# The cost is:  0.500000000000000

# %%
# Task-10

# Partial derivative functions example 4
def fpx(x, y):
    r = 3 ** (-x**2 - y**2)
    return (2 * x * np.log(3) * r) / (r + 1)**2

def fpy(x, y):
    r = 3 ** (-x**2 - y**2)
    return (2 * y * np.log(3) * r) / (r + 1)**2

# %%
# Setup
multiplier = 0.3
max_iter = 500
params = np.array([2.0, 2.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [0.0032479 0.0032479]
# Minimum occurs at x value of:  1.7968588439501891
# Minimum occurs at y value of:  1.7968588439501891
# The cost is:  0.9991707694321897

# %% [markdown]
# # Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.5
max_iter = 300
params = np.array([1.5, 2.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)
# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [1.53432945e-31 2.04577260e-31]
# Minimum occurs at x value of:  2.026048980299434e-31
# Minimum occurs at y value of:  2.7013986403992445e-31
# The cost is:  0.5

# %%
fig = plt.figure(figsize=[26, 22])
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.8)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# # Example 5 - Working with Data & a Real Cost Function

# %%
#sample data
x_5 = np.array([[0.3, 1.3, 2.3, 3.3, 4.3, 5.3]]).transpose()
y_5 = np.array([1.7, 2.4, 3.3, 3.5, 6.5, 9.5]).reshape(6, 1)
print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (6, 1)
# Shape of y_5 array: (6, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.3633333333333324
# Theta 1: 1.4714285714285715

# %%
plt.scatter(x_5, y_5, s=70)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=5)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[1.21435309]
#  [2.43707955]
#  [3.65980602]
#  [4.88253248]
#  [6.10525894]
#  [7.32798541]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.3]
#  [3.5]
#  [6.5]
#  [9.5]]

# %%
import numpy as np

def mse(y, y_hat):
    mse_calc = np.mean((y - y_hat)**2)
    return mse_calc

# Example usage: Assuming y_5 and y_hat are defined
print('MSE value: ', mse(y_5, y_hat))
# Out:
# MSE value:  1.1919253561423668

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: 1.1919253561423668
# MSE regression using manual calc is 1.1919253561423668
# MSE regression is 0.9665079365079364

# %% [markdown]
# # 3D Plot for the MSE Cost Function

# %%
nr_thetas = 400
th_0 = np.linspace(start=-2, stop=5, num=nr_thetas)
th_1 = np.linspace(start=-2, stop=5, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %%
# Calculate MSE using nested for loops

plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (400, 400)
# Shape of plot_t1 (400, 400)
# Shape of plot_cost (400, 400)

# %%
# Plotting MSE

fig = plt.figure(figsize=[18, 16])
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.cool)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9665604801477382
# Min occurs at (i,j): (198, 134)
# Min MSE for Theta 0 at plot_t0[111][91] 0.3508771929824559
# Min MSE for Theta 1 at plot_t1[111][91] 1.4736842105263155

# %% [markdown]
# # MSE & Gradient Descent

# %%
def grad(x, y, thetas):
    n = y.size
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.05
thetas = np.array([3.5, 2.9])

plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.363333333351392
# Min occurs at Theta 1: 1.4714285714237572
# MSE is: 0.9665079365079364

# %%
# Plotting MSE

fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)
ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
